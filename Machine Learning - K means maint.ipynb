# %%
# Step 1 : Import data 

import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Sample Data
data = {'X': [2.0, 2.5, 1.8, 5.0, 6.0, 6.5, 7.0, 8.0, 2.0, 4.0, 5.0, 3.5, 3.0, 4.5, 5.5, 9.0, 8.0, 7.5, 9.5, 8.5],
        'Y': [3.0, 4.0, 5.0, 8.0, 7.0, 8.0, 6.0, 7.0, 6.0, 7.0, 3.0, 5.0, 4.5, 5.5, 6.5, 8.0, 6.5, 6.0, 7.5, 7.0]}

df = pd.DataFrame(data)

# %%
# Elbow plot

sse = []
k_rng = range(1,10)
for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit(df[['X','Y']])
    sse.append(km.inertia_)
    
plt.xlabel('K')
plt.ylabel('Sum of squared error')
plt.plot(k_rng,sse)

# %%
# Step 3: Create a Model

kmeans = KMeans(n_clusters=3)

# %%
# Step 5: Train the Model

import warnings
warnings.filterwarnings("ignore")

kmeans.fit(df)
# Out:
# KMeans(n_clusters=3)

# %%
# Step 6: Make Predictions

df['Cluster'] = kmeans.predict(df)
df.head()
# Out:
#      X    Y  Cluster
# 0  2.0  3.0        1
# 1  2.5  4.0        1
# 2  1.8  5.0        1
# 3  5.0  8.0        2
# 4  6.0  7.0        2

# %%
# Visualization

plt.scatter(df['X'], df['Y'], c=df['Cluster'], cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1] marker='X', s=200, c='red')
plt.title('K-means Clustering')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
