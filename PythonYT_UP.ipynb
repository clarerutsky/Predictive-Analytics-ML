# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
s1 = pd.Series([1, 2, 3, 4, 4, 5])
print(s1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    4
# 5    5
# dtype: int64

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
s1.values
# Out:
# array([1, 2, 3, 4, 4, 5], dtype=int64)

# %%
s3 = pd.Series([1,2,3,5,7], index = [10,20,30,40,50])

# %%
s3
# Out:
# 10    1
# 20    2
# 30    3
# 40    5
# 50    7
# dtype: int64

# %%
scores = pd.Series([2,3,5,6,7], index =['Bob','Gorge','Alex','Fiona','sarah'])

# %%
scores
# Out:
# Bob      2
# Gorge    3
# Alex     5
# Fiona    6
# sarah    7
# dtype: int64

# %%
scores.index
# Out:
# Index(['Bob', 'Gorge', 'Alex', 'Fiona', 'sarah'], dtype='object')

# %%
scores.values
# Out:
# array([2, 3, 5, 6, 7], dtype=int64)

# %%
ds = {'Bob':3.2,'Gorge':4.5,'Alex':2.6,'Fiona':5,'Sarah':3.8}

# %%
s4 = pd.Series(ds)

# %%
s4
# Out:
# Bob      3.2
# Gorge    4.5
# Alex     2.6
# Fiona    5.0
# Sarah    3.8
# dtype: float64

# %%
s4.index
# Out:
# Index(['Bob', 'Gorge', 'Alex', 'Fiona', 'Sarah'], dtype='object')

# %%
s4.values
# Out:
# array([3.2, 4.5, 2.6, 5. , 3.8])

# %%
df1= pd.DataFrame()

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df1)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1.columns
# Out:
# RangeIndex(start=0, stop=0, step=1)

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=0, step=1)

# %%
students_list = [['Bob','William',26,'Computer Engeineering',36],
                ['Emma','Johnson',23,'Math',94],
                ['Sarah','Smith',22,'Chemistry',95],
                ['Alex','Brown',21,'Electrical Engineering',82]]

# %%
students_df = pd.DataFrame(students_list)

# %%
students_df
# Out:
#        0        1   2                       3   4
# 0    Bob  William  26   Computer Engeineering  36
# 1   Emma  Johnson  23                    Math  94
# 2  Sarah    Smith  22               Chemistry  95
# 3   Alex    Brown  21  Electrical Engineering  82

# %%
students_df = pd.DataFrame(students_list,columns =['First_Name','Last_Name','Age','Major','Score'])

# %%
students_df
# Out:
#   First_Name Last_Name  Age                   Major  Score
# 0        Bob   William   26   Computer Engeineering     36
# 1       Emma   Johnson   23                    Math     94
# 2      Sarah     Smith   22               Chemistry     95
# 3       Alex     Brown   21  Electrical Engineering     82

# %%
students_df = pd.DataFrame(students_list,index = ['Bob@mail.com','Emma@mail.com','Sarah@mail.com','Alex@mail.com'])

# %%
students_df
# Out:
#                     0        1   2                       3   4
# Bob@mail.com      Bob  William  26   Computer Engeineering  36
# Emma@mail.com    Emma  Johnson  23                    Math  94
# Sarah@mail.com  Sarah    Smith  22               Chemistry  95
# Alex@mail.com    Alex    Brown  21  Electrical Engineering  82

# %%
students_dict = {'First_Name':['Bob','Emma','Sarah','Alex'],
                'Last_Name':['William','Johnson','Smith','Brown'],
                'Age':[26,23,22,21],
                'Major':['Computer Engineering','Math','Chemistry','Electrical Engineering'],
                'Score':[86,92,95,85]}

# %%
students_df2 = pd.DataFrame(students_dict)

# %%
students_df2
# Out:
#   First_Name Last_Name  Age                   Major  Score
# 0        Bob   William   26    Computer Engineering     86
# 1       Emma   Johnson   23                    Math     92
# 2      Sarah     Smith   22               Chemistry     95
# 3       Alex     Brown   21  Electrical Engineering     85

# %%
students_df2 = pd.DataFrame(students_dict, columns = ['Last_Name','Score','City'])

# %%
students_df
# Out:
#                     0        1   2                       3   4
# Bob@mail.com      Bob  William  26   Computer Engeineering  36
# Emma@mail.com    Emma  Johnson  23                    Math  94
# Sarah@mail.com  Sarah    Smith  22               Chemistry  95
# Alex@mail.com    Alex    Brown  21  Electrical Engineering  82

# %%
students_df2
# Out:
#   Last_Name  Score City
# 0   William     86  NaN
# 1   Johnson     92  NaN
# 2     Smith     95  NaN
# 3     Brown     85  NaN

# %%
students_df.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
students_df.index
# Out:
# Index(['Bob@mail.com', 'Emma@mail.com', 'Sarah@mail.com', 'Alex@mail.com'], dtype='object')

# %%
students_df.shape
# Out:
# (4, 5)

# %%
students_df.head(2)
# Out:
#                   0        1   2                      3   4
# Bob@mail.com    Bob  William  26  Computer Engeineering  36
# Emma@mail.com  Emma  Johnson  23                   Math  94

# %%
students_df.tail(3)
# Out:
#                     0        1   2                       3   4
# Emma@mail.com    Emma  Johnson  23                    Math  94
# Sarah@mail.com  Sarah    Smith  22               Chemistry  95
# Alex@mail.com    Alex    Brown  21  Electrical Engineering  82

# %%
students_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Bob@mail.com to Alex@mail.com
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4 non-null      object
#  1   1       4 non-null      object
#  2   2       4 non-null      int64
#  3   3       4 non-null      object
#  4   4       4 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 192.0+ bytes

# %%
students_df.describe()
# Out:
#                2          4
# count   4.000000   4.000000
# mean   23.000000  76.750000
# std     2.160247  27.801379
# min    21.000000  36.000000
# 25%    21.750000  70.500000
# 50%    22.500000  88.000000
# 75%    23.750000  94.250000
# max    26.000000  95.000000

# %%
dm = pd.read_csv('C:\\Users\\BOOK\Documents\\PYTHON_FILES-X-Academy\\Datasets\\data_01.csv')

# %%
dm
# Out:
#       first name  last name  experience   score
# 0          Alex       Smith     Python       92
# 1         James       Jones        C++       97
# 2          Mary    Williams     Python       98
# 3      Patricia       Brown       Java       87
# 4      Jennifer      Taylor       HTML       88
# 5         Emily      Davies   Android        90
# 6       Michael      Wilson     Python       91
# 7       Jessica       Evans        C++       95
# 8          John      Thomas     Python       90
# 9        Thomas     Roberts       Java       89
# 10  Christopher      Martin     Python       83
# 11      Barbara         Lee        C++       86
# 12      Matthew    Anderson          R       97
# 13         Mark       White     Python       91
# 14        Nancy      Taylor       Java       96
# 15       Andrew       Smith          R       92

# %%
dm2 = pd.read_csv('C:\\Users\\BOOK\Documents\\PYTHON_FILES-X-Academy\\Datasets\\data_02.csv',header = None,names =['fname','lname','course','score'])

# %%
dm2
# Out:
#            fname      lname      course  score
# 0          Alex       Smith     Python      92
# 1         James       Jones        C++      97
# 2          Mary    Williams     Python      98
# 3      Patricia       Brown       Java      87
# 4      Jennifer      Taylor       HTML      88
# 5         Emily      Davies   Android       90
# 6       Michael      Wilson     Python      91
# 7       Jessica       Evans        C++      95
# 8          John      Thomas     Python      90
# 9        Thomas     Roberts       Java      89
# 10  Christopher      Martin     Python      83
# 11      Barbara         Lee        C++      86
# 12      Matthew    Anderson          R      97
# 13         Mark       White     Python      91
# 14        Nancy      Taylor       Java      96
# 15       Andrew       Smith          R      92

# %%
dm1 = pd.read_csv('C:\\Users\\BOOK\Documents\\PYTHON_FILES-X-Academy\\Datasets\\data_01.csv',skiprows = 1,names = ['a','b','c','d'])
dm1
# Out:
#                a          b           c   d
# 0          Alex       Smith     Python   92
# 1         James       Jones        C++   97
# 2          Mary    Williams     Python   98
# 3      Patricia       Brown       Java   87
# 4      Jennifer      Taylor       HTML   88
# 5         Emily      Davies   Android    90
# 6       Michael      Wilson     Python   91
# 7       Jessica       Evans        C++   95
# 8          John      Thomas     Python   90
# 9        Thomas     Roberts       Java   89
# 10  Christopher      Martin     Python   83
# 11      Barbara         Lee        C++   86
# 12      Matthew    Anderson          R   97
# 13         Mark       White     Python   91
# 14        Nancy      Taylor       Java   96
# 15       Andrew       Smith          R   92

# %%
dm3 = pd.read_csv('C:\\Users\\BOOK\Documents\\PYTHON_FILES-X-Academy\\Datasets\\data_03.csv',sep = '|')

# %%
dm3
# Out:
#       first name  last name  experience   score
# 0          Alex       Smith     Python       92
# 1         James       Jones        C++       97
# 2          Mary    Williams     Python       98
# 3      Patricia       Brown       Java       87
# 4      Jennifer      Taylor       HTML       88
# 5         Emily      Davies   Android        90
# 6       Michael      Wilson     Python       91
# 7       Jessica       Evans        C++       95
# 8          John      Thomas     Python       90
# 9        Thomas     Roberts       Java       89
# 10  Christopher      Martin     Python       83
# 11      Barbara         Lee        C++       86
# 12      Matthew    Anderson          R       97
# 13         Mark       White     Python       91
# 14        Nancy      Taylor       Java       96
# 15       Andrew       Smith          R       92

# %%
dm4 = pd.read_csv('C:\\Users\\BOOK\Documents\\PYTHON_FILES-X-Academy\\Datasets\\data_04.csv',comment ='#',sep ='\t')

# %%
dm4
# Out:
#       first name  last name  experience   score
# 0          Alex       Smith     Python       92
# 1         James       Jones        C++       97
# 2          Mary    Williams     Python       98
# 3      Patricia       Brown       Java       87
# 4      Jennifer      Taylor       HTML       88
# 5         Emily      Davies   Android        90
# 6       Michael      Wilson     Python       91
# 7       Jessica       Evans        C++       95
# 8          John      Thomas     Python       90
# 9        Thomas     Roberts       Java       89
# 10  Christopher      Martin     Python       83
# 11      Barbara         Lee        C++       86
# 12      Matthew    Anderson          R       97
# 13         Mark       White     Python       91
# 14        Nancy      Taylor       Java       96
# 15       Andrew       Smith          R       92

# %%
dm5 = pd.read_csv('C:\\Users\\BOOK\Documents\\PYTHON_FILES-X-Academy\\Datasets\\data_05.csv',skiprows = 3)

# %%
dm5
# Out:
#       first name  last name  experience   score
# 0          Alex       Smith     Python       92
# 1         James       Jones        C++       97
# 2          Mary    Williams     Python       98
# 3      Patricia       Brown       Java       87
# 4      Jennifer      Taylor       HTML       88
# 5         Emily      Davies   Android        90
# 6       Michael      Wilson     Python       91
# 7       Jessica       Evans        C++       95
# 8          John      Thomas     Python       90
# 9        Thomas     Roberts       Java       89
# 10  Christopher      Martin     Python       83
# 11      Barbara         Lee        C++       86
# 12      Matthew    Anderson          R       97
# 13         Mark       White     Python       91
# 14        Nancy      Taylor       Java       96
# 15       Andrew       Smith          R       92

# %%
 pro =pd.read_csv('C:\\Users\\BOOK\Documents\\PYTHON_FILES-X-Academy\\Datasets\\titanic.csv')

# %%
pro
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pro.shape
# Out:
# (891, 12)

# %%
pro.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
pro.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
age = pro['Age']

# %%
age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
type(age)
# Out:
# pandas.core.series.Series

# %%
age.mean()
# Out:
# 29.69911764705882

# %%
age.max()
# Out:
# 80.0

# %%
pro[['Name','Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
pro.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
pro.iloc[0,[1,4]]
# Out:
# Survived       0
# Sex         male
# Name: 0, dtype: object

# %%
pro.loc[0,['Survived','Sex']]
# Out:
# Survived       0
# Sex         male
# Name: 0, dtype: object

# %%
pro.iloc[:5,:3]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3

# %%
pro.iloc[[0,-1],-3:]
# Out:
#      Fare Cabin Embarked
# 0    7.25   NaN        S
# 890  7.75   NaN        Q

# %%
pro.loc[5:10,'Name':'Ticket']
# Out:
#                                                  Name     Sex   Age  SibSp  \
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
#
#     Parch   Ticket
# 5       0   330877
# 6       0    17463
# 7       1   349909
# 8       2   347742
# 9       0   237736
# 10      1  PP 9549

# %%
pro.Sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
pro.Sex == 'male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
pro.loc[pro.Sex == 'male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
pro.Sex =='female'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 886    True
# 887    True
# 888    True
# 889    True
# 890    True
# Name: Sex, Length: 891, dtype: bool

# %%
pro.Age > 35
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
pro.loc[(pro.Sex == 'female') & (pro.Age > 35)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J  female  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan  female  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# data cleaning

# %%
dc = pd.read_csv('C:\\Users\\BOOK\Documents\\PYTHON_FILES-X-Academy\\Datasets\\titanic.csv')

# %%
dc
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dc.isna() #check missing value
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
dc.isna().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
dc2 = dc.dropna(axis = 0)  #axis 0 is row while set it to 1 is column

# %%
dc2
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dc2.isna().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
print(dc.shape,dc2.shape)
# Out:
# (891, 12) (183, 12)

# %%
dc.dropna(inplace = True)

# %%
dc.shape
# Out:
# (183, 12)

# %%
new_df = pd.read_csv('C:\\Users\\BOOK\Documents\\PYTHON_FILES-X-Academy\\Datasets\\titanic.csv')

# %%
new_df.fillna(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
new_df.isna().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
dcs1 = new_df.fillna(new_df.mean(numeric_only = True))

# %%
dcs1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
dcs2 = dcs1.fillna(new_df.mode().iloc[0])

# %%
dcs2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
dcs2.isna().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
#Duplicate

# %%
new_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
new_df.duplicated().any()
# Out:
# False

# %%
df_duplicate = pd.concat((new_df,new_df.iloc[:3]))

# %%
df_duplicate
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 889          890         1       1
# 890          891         0       3
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
DTS = pd.read_csv('C:\\Users\\BOOK\Documents\\PYTHON_FILES-X-Academy\\Datasets\\employees.csv')

# %%
DTS.shape
# Out:
# (1000, 8)

# %%
DTS.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
DTS.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
DTS.Gender
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995       NaN
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
DTS.rename({'First Name': 'First_Name', 'Start Date':'Start_Date', 'Last Login Time':'Last_Login_Time',
       'Bonus %':'Bonus',  'Senior Management':'Senior_Management'},axis= 1)
# Out:
#     First_Name  Gender  Start_Date Last_Login_Time  Salary   Bonus  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933   4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705   9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004   1.389
# ..         ...     ...         ...             ...     ...     ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483  16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949  10.169
#
#     Senior_Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
DTS.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
DTS.rename({'First Name': 'First_Name', 'Start Date':'Start_Date', 'Last Login Time':'Last_Login_Time',
       'Bonus %':'Bonus',  'Senior Management':'Senior_Management'},axis= 1,inplace = True)

# %%
DTS.columns
# Out:
# Index(['First_Name', 'Gender', 'Start_Date', 'Last_Login_Time', 'Salary',
#        'Bonus', 'Senior_Management', 'Team'],
#       dtype='object')

# %%
DTS
# Out:
#     First_Name  Gender  Start_Date Last_Login_Time  Salary   Bonus  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933   4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705   9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004   1.389
# ..         ...     ...         ...             ...     ...     ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483  16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949  10.169
#
#     Senior_Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
DTS.Bonus.round()
# Out:
# 0       7.0
# 1       4.0
# 2      12.0
# 3       9.0
# 4       1.0
#        ...
# 995    17.0
# 996    20.0
# 997     1.0
# 998    12.0
# 999    10.0
# Name: Bonus, Length: 1000, dtype: float64

# %%
DTS['Bonus2'] = DTS.Bonus.round()

# %%
DTS # NEW COLUMN is called derived column
# Out:
#     First_Name  Gender  Start_Date Last_Login_Time  Salary   Bonus  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933   4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705   9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004   1.389
# ..         ...     ...         ...             ...     ...     ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483  16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949  10.169
#
#     Senior_Management                  Team  Bonus2
# 0                True             Marketing     7.0
# 1                True                   NaN     4.0
# ...

# %%
#writing new column istead of derived

# %%
import numpy as np

# %%
DTS['random'] = pd.Series(np.random.randint(0,10,1000))

# %%
DTS
# Out:
#     First_Name  Gender  Start_Date Last_Login_Time  Salary   Bonus  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933   4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705   9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004   1.389
# ..         ...     ...         ...             ...     ...     ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483  16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949  10.169
#
#     Senior_Management                  Team  Bonus2  random
# 0                True             Marketing     7.0       0
# ...

# %%
DTS1 = DTS.iloc[:2]

# %%
DTS1
# Out:
#   First_Name Gender Start_Date Last_Login_Time  Salary  Bonus  \
# 0    Douglas   Male   8/6/1993        12:42 PM   97308  6.945
# 1     Thomas   Male  3/31/1996         6:53 AM   61933  4.170
#
#   Senior_Management       Team  Bonus2  random
# 0              True  Marketing     7.0       0
# 1              True        NaN     4.0       6

# %%
DTS2 = pd.concat((DTS, DTS1), axis = 0)

# %%
DTS2
# Out:
#     First_Name  Gender Start_Date Last_Login_Time  Salary   Bonus  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933   4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705   9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004   1.389
# ..         ...     ...        ...             ...     ...     ...
# 997    Russell    Male  5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949  10.169
# 0      Douglas    Male   8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933   4.170
#
#     Senior_Management                  Team  Bonus2  random
# 0                True             Marketing     7.0       0
# ...

# %%
DTS2 = pd.concat((DTS, DTS1), axis = 0,ignore_index = True)
DTS2
# Out:
#      First_Name  Gender Start_Date Last_Login_Time  Salary   Bonus  \
# 0       Douglas    Male   8/6/1993        12:42 PM   97308   6.945
# 1        Thomas    Male  3/31/1996         6:53 AM   61933   4.170
# 2         Maria  Female  4/23/1993        11:17 AM  130590  11.858
# 3         Jerry    Male   3/4/2005         1:00 PM  138705   9.340
# 4         Larry    Male  1/24/1998         4:47 PM  101004   1.389
# ...         ...     ...        ...             ...     ...     ...
# 997     Russell    Male  5/20/2013        12:39 PM   96914   1.421
# 998       Larry    Male  4/20/2013         4:45 PM   60500  11.985
# 999      Albert    Male  5/15/2012         6:24 PM  129949  10.169
# 1000    Douglas    Male   8/6/1993        12:42 PM   97308   6.945
# 1001     Thomas    Male  3/31/1996         6:53 AM   61933   4.170
#
#      Senior_Management                  Team  Bonus2  random
# 0                 True             Marketing     7.0       0
# ...

# %%
DTS3 = DTS.drop(['First_Name'],axis = 1)

DTS3
# Out:
#      Gender  Start_Date Last_Login_Time  Salary   Bonus Senior_Management  \
# 0      Male    8/6/1993        12:42 PM   97308   6.945              True
# 1      Male   3/31/1996         6:53 AM   61933   4.170              True
# 2    Female   4/23/1993        11:17 AM  130590  11.858             False
# 3      Male    3/4/2005         1:00 PM  138705   9.340              True
# 4      Male   1/24/1998         4:47 PM  101004   1.389              True
# ..      ...         ...             ...     ...     ...               ...
# 995     NaN  11/23/2014         6:09 AM  132483  16.655             False
# 996    Male   1/31/1984         6:30 AM   42392  19.675             False
# 997    Male   5/20/2013        12:39 PM   96914   1.421             False
# 998    Male   4/20/2013         4:45 PM   60500  11.985             False
# 999    Male   5/15/2012         6:24 PM  129949  10.169              True
#
#                      Team  Bonus2  random
# ...

# %%
DTS.drop(range(5), axis =0)
 
DTS
# Out:
#     First_Name  Gender  Start_Date Last_Login_Time  Salary   Bonus  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933   4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705   9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004   1.389
# ..         ...     ...         ...             ...     ...     ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483  16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949  10.169
#
#     Senior_Management                  Team  Bonus2  random
# 0                True             Marketing     7.0       0
# ...

# %%
# DATA TRansformation

# %%
data = pd.read_csv('C:\\Users\\BOOK\Documents\\PYTHON_FILES-X-Academy\\Datasets\\employees.csv')

# %%
data
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
data.Gender.value_counts()
# Out:
# Gender
# Female    431
# Male      424
# Name: count, dtype: int64

# %%
data.Gender.isna().sum()
# Out:
# 145

# %%
data['Gender2'] = pd.Categorical(data.Gender) # converting to categories reduces memory usage

# %%
data.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team Gender2
# 0              True        Marketing    Male
# 1              True              NaN    Male
# 2             False          Finance  Female
# 3              True          Finance    Male
# 4              True  Client Services    Male

# %%
data.memory_usage()
# Out:
# Index                 132
# First Name           8000
# Gender               8000
# Start Date           8000
# Last Login Time      8000
# Salary               8000
# Bonus %              8000
# Senior Management    8000
# Team                 8000
# Gender2              1124
# dtype: int64

# %%
import random

# %%
data['Scores'] = pd.Series(random.choices(['very low','low','medium','high','very high'], k = 1000)) # k parameter show the length of the list,we have 1000 employee we set the len to 1000

# %%
data.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team Gender2    Scores
# 0              True        Marketing    Male      high
# 1              True              NaN    Male       low
# 2             False          Finance  Female       low
# 3              True          Finance    Male  very low
# 4              True  Client Services    Male    medium

# %%
data.dtypes
# Out:
# First Name             object
# Gender                 object
# Start Date             object
# Last Login Time        object
# Salary                  int64
# Bonus %               float64
# Senior Management      object
# Team                   object
# Gender2              category
# Scores                 object
# dtype: object

# %%
pd.Categorical(data.Scores) # by default categories are sorted by lexical order
# Out:
# ['low', 'high', 'low', 'very high', 'very low', ..., 'medium', 'low', 'low', 'high', 'high']
# Length: 1000
# Categories (5, object): ['high', 'low', 'medium', 'very high', 'very low']

# %%
data['Score2'] = pd.Categorical(data.Scores,categories =['very Low','Low','Medium','High','Very High'],ordered=True)

# %%
sum(data.Score2 >'Medium')
# Out:
# 0

# %%
data.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team     Scores Score2
# 0              True        Marketing   very low    NaN
# 1              True              NaN  very high    NaN
# 2             False          Finance  very high    NaN
# 3              True          Finance  very high    NaN
# 4              True  Client Services   very low    NaN

# %%
data.Salary.min()
# Out:
# 35013

# %%
data.Salary.max()
# Out:
# 149908

# %%
data['cat_salary'] = pd.cut(data.Salary,bins =[35000,50000,75000,10000,125000,15000],
        labels = ['very low','low','medium','high','very high'])

# %%
data
